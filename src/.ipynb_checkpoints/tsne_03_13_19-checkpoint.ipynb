# %%
# import statements
import pandas as pd
from sklearn.cluster import KMeans
import sklearn
import matplotlib.pyplot as plt
import numpy as np
import sklearn.preprocessing as preproc
import seaborn as sb
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering

# %%
tfidf_path = '/Users/jackie16201/Desktop/Lab/clustering/data/tfidf'
tfidf = pd.read_csv(tfidf_path)

# %%
tfidf_nolabel = tfidf.iloc[:,1:]
tfidf_scaled = preproc.scale(tfidf_nolabel)

# %%
# utilize my test set
test_path = '/Users/jackie16201/Desktop/Lab/clustering/data/'
test_set = pd.read_csv(test_path + 'test_drugs', header=None)

# get the test set drugs from the tfidf matrix
test_set_strings = test_set.iloc[:,1]
tfidf_drug_names = tfidf.iloc[:,0]

# use boolean indexing to get the logical array of the intersection of the test set and tfidf
logical_drug_arr = tfidf_drug_names.isin(test_set_strings)
tfidf_test = tfidf_nolabel[logical_drug_arr]

# %%
def tryNumComponents(numComp):
    pca = sklearn.decomposition.PCA(n_components=numComp)
    pca.fit(tfidf_scaled)                 
    print 'first n components: ' + str((pca.explained_variance_ratio_))
    print 'sum: ' + str((np.sum(pca.explained_variance_ratio_)))

# %%
tryNumComponents(50)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  0.00236336 0.00210052 0.00201037
#  0.001928   0.00178957 0.00169111 0.00164132 0.00156224 0.00152807
#  0.00145189 0.00140821 0.00138406 0.00133262 0.00126782 0.00124776
#  0.00118789 0.0011001  0.00109044 0.00108317 0.0010533  0.00102549
#  0.00100679 0.00098661 0.00095591 0.00094274 0.00093744 0.00093081
#  0.00091337 0.00090536 0.0008975  0.00088863 0.00087444 0.00086771
#  0.00085882 0.00084378 0.00084168 0.00083483 0.00082593 0.0008159
#  0.00080775 0.00079561 0.00079271 0.00078731 0.00078647 0.00077618
#  0.00077177 0.00076097]
# sum: 0.06384493160105877

# %%
tryNumComponents(100)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  0.00236336 0.00210052 0.00201037
#  0.00192801 0.00178957 0.00169112 0.00164134 0.00156226 0.0015281
#  0.00145199 0.00140826 0.00138418 0.00133276 0.00126817 0.00124802
#  0.00118861 0.00110131 0.00109191 0.00108502 0.001056   0.00103001
#  0.00101207 0.00099193 0.00096287 0.00095291 0.00094734 0.00094459
#  0.00092185 0.0009128  0.0009094  0.00089929 0.00089229 0.0008838
#  0.00087682 0.00086634 0.00086009 0.00085551 0.00085049 0.00084572
#  0.00084176 0.00082771 0.00082237 0.00081895 0.00080576 0.00080364
#  0.00080145 0.0007981  0.00079687 0.00078609 0.00078235 0.00077941
#  0.00077635 0.00077019 0.0007669  0.00076441 0.00076098 0.00075851
#  0.00075591 0.00075241 0.00074668 0.00074558 0.0007412  0.00073593
#  0.00073168 0.00072933 0.00072626 0.00072391 0.00072222 0.00071596
#  0.00071366 0.0007119  0.00070802 0.00070477 0.00070011 0.00069512
#  0.00069267 0.00068901 0.00068308 0.00068226 0.00067906 0.00067726
#  0.00067496 0.00066661 0.00066409 0.00066034 0.00065387 0.00065126
#  0.00064698 0.00064217 0.00063929 0.00063724 0.00063294 0.00062243
#  0.00061786 0.00061566 0.00061451 0.00060981]
# sum: 0.09951340663216154

# %%
tryNumComponents(200)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  0.00236336 0.00210052 0.00201037
#  0.00192801 0.00178957 0.00169112 0.00164135 0.00156226 0.00152811
#  0.00145199 0.00140826 0.00138419 0.00133278 0.00126818 0.00124804
#  0.00118868 0.00110145 0.00109219 0.00108509 0.00105623 0.00103029
#  0.00101247 0.00099249 0.00096338 0.00095393 0.00094843 0.00094504
#  0.00092267 0.00091397 0.00091081 0.00090019 0.00089407 0.00088479
#  0.00087874 0.00086952 0.00086216 0.00085715 0.00085317 0.00084828
#  0.00084514 0.00083146 0.00082487 0.00082239 0.00081265 0.00080848
#  0.00080569 0.00080302 0.00080162 0.00079209 0.00079019 0.0007869
#  0.0007816  0.00077665 0.00077233 0.00077214 0.00076893 0.00076619
#  0.00076261 0.00076116 0.0007582  0.00075343 0.0007518  0.00074489
#  0.00074348 0.00074075 0.00073895 0.00073628 0.00073138 0.00072735
#  0.00072465 0.000722   0.00072113 0.00071544 0.00071344 0.00071039
#  0.00070992 0.00070703 0.00070222 0.00070024 0.0006977  0.00069389
#  0.00069071 0.00068636 0.00068431 0.00068279 0.00067964 0.00067623
#  0.0006731  0.00066903 0.00066536 0.00066304 0.00066107 0.00065841
#  0.00065422 0.0006521  0.00065152 0.00064696 0.00064628 0.00064284
#  0.00063973 0.00063576 0.00063516 0.00063445 0.00063162 0.00062937
#  0.00062666 0.00062603 0.00062367 0.00061871 0.00061527 0.00061422
#  0.00061081 0.00061065 0.00060641 0.00060459 0.00060221 0.0005998
#  0.00059862 0.00059451 0.00059398 0.00059094 0.00058972 0.00058815
#  0.00058491 0.00058302 0.00058231 0.0005809  0.00057672 0.00057579
#  0.00057305 0.00057141 0.0005712  0.00056684 0.0005645  0.00056304
#  0.00056033 0.00055907 0.00055635 0.00055536 0.00055445 0.00055357
#  0.00055061 0.00054825 0.00054681 0.00054441 0.00054324 0.00054293
#  0.00054077 0.00053986 0.00053872 0.00053706 0.00053592 0.00053459
#  0.00053301 0.0005305  0.00052754 0.00052699 0.00052667 0.00052178
#  0.00052114 0.00051935 0.00051895 0.00051707 0.00051659 0.00051345
#  0.0005126  0.00051002 0.00050842 0.00050781 0.0005061  0.00050534
#  0.00050428 0.00050176 0.00050055 0.00049857 0.00049803 0.00049612
#  0.00049505 0.00049423 0.00049178 0.00049085 0.00048974 0.00048794
#  0.00048699 0.00048512 0.00048314 0.00048055 0.00047852 0.00047703
#  0.00047489 0.00047428 0.00047413 0.00047211 0.0004692  0.00046721
#  0.00046696 0.00046578]
# sum: 0.15506366482347306

# %%
tryNumComponents(400)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  0.00236336 0.00210052 0.00201037
#  0.00192801 0.00178957 0.00169112 0.00164135 0.00156226 0.00152811
#  0.00145199 0.00140827 0.00138419 0.00133278 0.00126818 0.00124804
#  0.00118868 0.00110146 0.00109219 0.0010851  0.00105623 0.00103031
#  0.00101248 0.00099251 0.00096339 0.00095395 0.00094846 0.00094507
#  0.00092272 0.00091401 0.00091085 0.00090022 0.00089414 0.00088489
#  0.00087883 0.00086959 0.00086228 0.00085724 0.00085329 0.00084844
#  0.00084523 0.00083162 0.00082508 0.00082259 0.00081293 0.00080873
#  0.00080605 0.00080327 0.00080185 0.00079252 0.00079056 0.00078736
#  0.00078195 0.00077692 0.00077287 0.00077244 0.00076938 0.00076676
#  0.00076321 0.00076158 0.00075874 0.00075403 0.00075237 0.00074549
#  0.00074403 0.00074122 0.00073964 0.00073678 0.00073206 0.00072812
#  0.00072548 0.00072281 0.00072199 0.0007163  0.00071431 0.00071111
#  0.00071084 0.00070858 0.00070315 0.00070172 0.00069905 0.00069525
#  0.00069271 0.00068746 0.00068601 0.00068451 0.00068157 0.00067785
#  0.00067616 0.00067107 0.00066827 0.000665   0.00066359 0.00066075
#  0.00065733 0.00065511 0.00065426 0.00065083 0.00064968 0.00064556
#  0.00064304 0.00063984 0.00063848 0.00063812 0.00063495 0.00063437
#  0.00063103 0.00062972 0.00062851 0.00062453 0.0006209  0.00061978
#  0.00061575 0.00061471 0.00061112 0.0006093  0.00060722 0.00060503
#  0.00060475 0.00060274 0.00060254 0.0005989  0.00059743 0.00059591
#  0.00059191 0.00059012 0.00058879 0.00058754 0.00058641 0.00058421
#  0.00058374 0.00057965 0.00057893 0.00057633 0.00057588 0.00057357
#  0.0005715  0.00056983 0.00056867 0.0005662  0.0005649  0.00056397
#  0.00056198 0.00055983 0.0005594  0.00055828 0.0005577  0.00055619
#  0.00055578 0.00055281 0.00055188 0.00054969 0.00054855 0.00054801
#  0.00054657 0.0005461  0.00054532 0.00054257 0.00054055 0.00053975
#  0.00053819 0.00053695 0.00053505 0.00053441 0.00053293 0.00053164
#  0.00053074 0.00053015 0.00052828 0.00052798 0.00052585 0.00052474
#  0.00052415 0.0005222  0.00052154 0.00052074 0.00052006 0.00051881
#  0.00051643 0.00051588 0.0005157  0.00051485 0.00051364 0.00051224
#  0.00051141 0.00051069 0.00050986 0.00050905 0.00050681 0.00050596
#  0.00050546 0.00050521 0.00050368 0.00050362 0.00050234 0.00050179
#  0.00050064 0.0004998  0.00049793 0.0004975  0.0004966  0.00049513
#  0.00049468 0.00049359 0.00049241 0.00049147 0.00049047 0.00048983
#  0.00048909 0.00048747 0.00048715 0.00048607 0.00048484 0.00048444
#  0.00048439 0.00048323 0.00048274 0.0004814  0.00048038 0.0004801
#  0.00047989 0.00047839 0.0004776  0.00047719 0.00047695 0.00047547
#  0.00047489 0.0004741  0.0004725  0.0004719  0.0004717  0.00046975
#  0.00046911 0.00046842 0.00046799 0.0004663  0.00046602 0.00046491
#  0.00046472 0.00046411 0.00046325 0.00046211 0.00046192 0.00046105
#  0.00045988 0.00045933 0.00045914 0.00045824 0.00045732 0.00045664
#  0.00045561 0.00045474 0.00045397 0.00045339 0.00045292 0.00045202
#  0.00045189 0.00045151 0.00045017 0.00044962 0.00044894 0.00044779
#  0.0004477  0.00044659 0.0004461  0.00044547 0.00044388 0.00044307
#  0.0004426  0.00044138 0.00044098 0.00044045 0.00044031 0.00043997
#  0.00043934 0.00043833 0.00043759 0.00043711 0.00043562 0.00043544
#  0.00043407 0.00043385 0.00043321 0.00043256 0.00043158 0.00043099
#  0.00043014 0.00042995 0.00042937 0.00042875 0.00042824 0.0004276
#  0.00042693 0.00042615 0.00042516 0.00042439 0.00042425 0.00042328
#  0.00042187 0.00042126 0.00042087 0.00041987 0.00041898 0.00041862
#  0.00041785 0.00041721 0.00041684 0.00041642 0.00041567 0.00041526
#  0.00041446 0.00041352 0.00041295 0.00041226 0.000412   0.00041137
#  0.0004107  0.0004105  0.0004098  0.00040883 0.00040792 0.00040769
#  0.0004074  0.00040686 0.00040602 0.00040564 0.00040537 0.00040457
#  0.00040357 0.00040281 0.00040256 0.0004021  0.00040168 0.00040063
#  0.0003986  0.00039828 0.00039827 0.00039775 0.00039745 0.0003965
#  0.00039616 0.00039536 0.00039486 0.00039438 0.00039341 0.00039305
#  0.00039241 0.00039122 0.00039106 0.00039029 0.00038918 0.00038898
#  0.00038858 0.0003883  0.00038761 0.00038641 0.00038571 0.00038491
#  0.0003846  0.00038341 0.00038263 0.00038238 0.00038204 0.00038085
#  0.00038071 0.00038018 0.00037959 0.00037926 0.00037804 0.00037753
#  0.00037673 0.00037656 0.00037624 0.00037462 0.00037421 0.00037342
#  0.00037242 0.00037203 0.00037136 0.00037086 0.00037027 0.00036943
#  0.00036897 0.00036867 0.00036693 0.00036589 0.0003655  0.00036462
#  0.0003642  0.00036306 0.00036279 0.00036205 0.00036091 0.00036062
#  0.0003595  0.00035861 0.00035793 0.00035682]
# sum: 0.2415337180113335

# %%
tryNumComponents(1000)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  0.00236336 0.00210052 0.00201037
#  0.00192801 0.00178957 0.00169112 0.00164135 0.00156226 0.00152811
#  0.00145199 0.00140826 0.00138419 0.00133278 0.00126818 0.00124804
#  0.00118868 0.00110145 0.00109219 0.00108509 0.00105623 0.0010303
#  0.00101248 0.00099251 0.00096339 0.00095394 0.00094845 0.00094506
#  0.00092271 0.000914   0.00091083 0.00090021 0.00089413 0.00088488
#  0.00087882 0.00086958 0.00086227 0.00085723 0.00085328 0.00084842
#  0.00084522 0.00083161 0.00082507 0.00082258 0.00081291 0.00080871
#  0.00080602 0.00080325 0.00080183 0.00079249 0.00079054 0.00078734
#  0.00078193 0.0007769  0.00077285 0.00077243 0.00076935 0.00076674
#  0.00076319 0.00076155 0.00075871 0.00075401 0.00075235 0.00074546
#  0.00074401 0.00074119 0.00073961 0.00073675 0.00073204 0.00072809
#  0.00072545 0.00072278 0.00072197 0.00071627 0.0007143  0.00071108
#  0.0007108  0.00070856 0.00070315 0.0007017  0.00069904 0.00069523
#  0.00069268 0.00068746 0.00068597 0.0006845  0.00068156 0.00067785
#  0.00067615 0.00067105 0.00066826 0.00066496 0.00066358 0.00066074
#  0.00065733 0.00065506 0.00065426 0.00065084 0.00064967 0.00064554
#  0.00064303 0.00063981 0.00063847 0.00063813 0.00063495 0.00063445
#  0.00063102 0.00062972 0.00062855 0.00062451 0.00062097 0.00061978
#  0.00061586 0.00061481 0.00061122 0.00060937 0.00060725 0.00060511
#  0.00060486 0.00060286 0.00060259 0.00059899 0.00059753 0.00059614
#  0.00059199 0.00059021 0.00058893 0.00058773 0.00058654 0.00058435
#  0.00058387 0.00057989 0.00057914 0.00057665 0.00057598 0.00057378
#  0.0005717  0.00057017 0.00056899 0.00056668 0.00056531 0.00056427
#  0.00056227 0.00056037 0.00055963 0.00055879 0.00055791 0.00055652
#  0.00055626 0.00055322 0.00055221 0.00055049 0.00054904 0.0005484
#  0.00054694 0.00054659 0.00054578 0.00054332 0.00054131 0.00054031
#  0.00053883 0.00053765 0.00053588 0.00053487 0.00053356 0.0005322
#  0.00053155 0.00053115 0.00052921 0.00052883 0.00052645 0.00052554
#  0.00052529 0.00052368 0.00052262 0.00052208 0.00052065 0.00051968
#  0.0005173  0.00051711 0.00051646 0.00051589 0.00051479 0.000514
#  0.00051249 0.00051207 0.00051147 0.00051032 0.00050841 0.00050742
#  0.00050711 0.00050628 0.0005056  0.00050504 0.00050364 0.00050358
#  0.00050153 0.00050126 0.00049953 0.00049906 0.00049857 0.00049754
#  0.00049629 0.00049557 0.00049421 0.00049332 0.00049292 0.00049203
#  0.00049134 0.00049026 0.00048923 0.00048849 0.00048714 0.00048654
#  0.00048606 0.00048576 0.00048541 0.00048414 0.00048305 0.0004828
#  0.00048141 0.00048098 0.00048032 0.00047982 0.0004791  0.00047795
#  0.00047749 0.00047626 0.00047579 0.00047472 0.00047386 0.00047331
#  0.00047182 0.00047142 0.0004712  0.00047023 0.00046985 0.00046971
#  0.00046883 0.00046791 0.00046715 0.00046622 0.00046573 0.00046524
#  0.00046439 0.00046361 0.00046296 0.0004615  0.00046112 0.00046059
#  0.00046031 0.00045897 0.00045856 0.00045835 0.00045794 0.00045681
#  0.00045602 0.00045557 0.00045535 0.00045473 0.00045426 0.00045323
#  0.00045216 0.00045072 0.00045027 0.00044997 0.00044937 0.00044836
#  0.0004477  0.00044729 0.00044675 0.00044588 0.00044556 0.00044529
#  0.00044471 0.00044397 0.00044344 0.00044299 0.00044245 0.00044206
#  0.00044105 0.00044067 0.00043996 0.00043972 0.00043921 0.00043812
#  0.00043736 0.00043707 0.00043563 0.00043533 0.00043494 0.00043422
#  0.00043401 0.00043305 0.00043275 0.00043225 0.0004316  0.00043142
#  0.00043051 0.00042968 0.00042931 0.00042871 0.0004284  0.00042784
#  0.00042715 0.00042685 0.00042663 0.00042592 0.00042545 0.00042486
#  0.00042469 0.00042426 0.00042294 0.00042249 0.00042209 0.00042149
#  0.00042128 0.00042105 0.00042065 0.00042045 0.0004196  0.00041842
#  0.00041781 0.00041763 0.00041719 0.00041671 0.00041592 0.00041568
#  0.0004148  0.00041437 0.00041389 0.00041369 0.00041318 0.00041287
#  0.00041258 0.00041212 0.00041203 0.00041122 0.00040992 0.00040986
#  0.00040907 0.00040873 0.00040825 0.00040816 0.00040757 0.00040707
#  0.00040702 0.0004063  0.0004057  0.00040505 0.00040453 0.00040443
#  0.00040385 0.00040338 0.00040298 0.00040274 0.00040212 0.0004017
#  0.00040167 0.00040101 0.00040078 0.00040015 0.00039956 0.00039906
#  0.00039884 0.00039773 0.00039734 0.00039626 0.00039608 0.00039568
#  0.00039539 0.00039499 0.00039472 0.00039436 0.00039434 0.00039354
#  0.00039327 0.00039261 0.00039243 0.00039197 0.00039192 0.0003914
#  0.00039067 0.00039029 0.00038983 0.00038963 0.00038924 0.00038896
#  0.00038846 0.00038807 0.00038758 0.00038737 0.00038682 0.0003867
#  0.00038578 0.00038531 0.00038501 0.00038463 0.00038377 0.00038351
#  0.00038326 0.0003829  0.00038261 0.00038197 0.00038126 0.0003811
#  0.00038097 0.00038085 0.00038023 0.00037985 0.00037949 0.00037936
#  0.00037894 0.00037841 0.00037794 0.00037711 0.00037701 0.00037653
#  0.00037604 0.0003758  0.0003754  0.00037508 0.00037454 0.00037412
#  0.00037398 0.00037356 0.00037323 0.00037315 0.0003726  0.00037209
#  0.00037177 0.00037175 0.00037116 0.00037092 0.00037009 0.00036997
#  0.0003697  0.00036929 0.00036888 0.00036869 0.00036829 0.000368
#  0.00036771 0.00036727 0.00036636 0.00036621 0.00036582 0.00036552
#  0.0003653  0.00036499 0.00036416 0.00036397 0.0003635  0.00036319
#  0.00036281 0.00036212 0.00036179 0.00036156 0.00036136 0.00036113
#  0.00036086 0.00036059 0.00036023 0.00035975 0.00035922 0.00035905
#  0.00035849 0.00035817 0.00035789 0.00035749 0.00035745 0.00035717
#  0.00035672 0.00035639 0.0003559  0.00035578 0.00035482 0.00035467
#  0.00035454 0.0003542  0.00035376 0.00035362 0.00035328 0.00035292
#  0.00035265 0.00035209 0.00035197 0.00035178 0.00035134 0.0003512
#  0.00035061 0.00035029 0.00034978 0.00034963 0.00034908 0.00034896
#  0.00034861 0.00034857 0.00034826 0.00034794 0.00034767 0.00034696
#  0.00034669 0.00034655 0.00034633 0.00034574 0.0003456  0.0003452
#  0.00034483 0.00034438 0.00034417 0.00034391 0.00034366 0.00034324
#  0.00034316 0.00034285 0.00034239 0.00034205 0.00034163 0.00034139
#  0.0003411  0.00034086 0.00034059 0.00034049 0.00034027 0.00033962
#  0.00033939 0.0003392  0.00033884 0.00033867 0.00033846 0.00033772
#  0.0003373  0.0003372  0.00033674 0.00033637 0.00033608 0.00033597
#  0.00033548 0.00033528 0.00033494 0.0003349  0.00033465 0.00033444
#  0.00033377 0.00033354 0.00033319 0.00033276 0.00033273 0.00033224
#  0.00033197 0.00033175 0.00033147 0.00033111 0.00033089 0.00033074
#  0.00033064 0.00033013 0.00032992 0.00032954 0.00032929 0.00032893
#  0.00032847 0.0003283  0.00032804 0.00032787 0.00032783 0.00032744
#  0.00032735 0.00032696 0.00032666 0.00032631 0.00032573 0.00032556
#  0.00032549 0.00032511 0.00032488 0.00032458 0.00032417 0.00032379
#  0.00032363 0.00032353 0.00032323 0.00032296 0.00032253 0.00032248
#  0.00032214 0.00032172 0.00032143 0.00032131 0.00032065 0.00032061
#  0.00032037 0.00031992 0.00031967 0.00031949 0.00031935 0.00031916
#  0.0003187  0.00031858 0.00031819 0.00031791 0.00031774 0.00031745
#  0.00031732 0.00031679 0.00031666 0.00031651 0.0003162  0.00031605
#  0.00031557 0.00031541 0.00031519 0.00031499 0.00031458 0.00031449
#  0.00031434 0.00031388 0.00031354 0.00031336 0.00031291 0.00031268
#  0.00031232 0.00031211 0.0003119  0.0003117  0.00031108 0.00031083
#  0.00031054 0.00031038 0.00031015 0.00030996 0.00030989 0.00030968
#  0.00030936 0.00030887 0.00030866 0.00030859 0.00030839 0.00030796
#  0.0003077  0.00030746 0.00030725 0.00030687 0.0003065  0.00030642
#  0.00030623 0.00030608 0.00030579 0.00030565 0.00030538 0.00030499
#  0.00030482 0.0003045  0.00030418 0.00030414 0.00030371 0.00030347
#  0.00030318 0.00030294 0.00030291 0.00030274 0.00030255 0.00030221
#  0.00030182 0.00030162 0.00030139 0.00030113 0.00030097 0.00030048
#  0.00030045 0.00030033 0.00029998 0.00029964 0.00029951 0.0002993
#  0.00029911 0.00029888 0.00029882 0.00029832 0.00029801 0.00029763
#  0.00029733 0.00029716 0.00029694 0.00029685 0.00029654 0.00029629
#  0.00029606 0.00029559 0.00029537 0.00029518 0.00029491 0.00029475
#  0.00029456 0.00029413 0.00029406 0.00029395 0.00029361 0.00029334
#  0.00029314 0.00029306 0.00029264 0.00029263 0.00029249 0.0002922
#  0.00029192 0.00029165 0.00029141 0.00029124 0.00029097 0.00029064
#  0.00029027 0.00029008 0.00028995 0.00028983 0.00028956 0.00028948
#  0.00028938 0.00028909 0.00028888 0.0002885  0.0002883  0.00028802
#  0.00028788 0.00028732 0.0002873  0.00028727 0.00028698 0.0002866
#  0.00028636 0.0002861  0.00028602 0.00028582 0.00028546 0.00028525
#  0.00028502 0.0002849  0.00028484 0.00028452 0.0002843  0.00028398
#  0.00028372 0.00028343 0.00028323 0.00028307 0.00028294 0.00028284
#  0.00028243 0.00028232 0.00028207 0.00028191 0.00028171 0.00028154
#  0.00028108 0.00028086 0.0002806  0.00028049 0.00028012 0.00028005
#  0.00027998 0.00027989 0.00027969 0.00027927 0.000279   0.00027855
#  0.00027839 0.00027837 0.0002779  0.0002777  0.00027754 0.00027735
#  0.00027733 0.00027683 0.00027659 0.00027631 0.00027613 0.00027602
#  0.00027588 0.00027546 0.00027527 0.00027505 0.00027498 0.00027472
#  0.0002744  0.0002743  0.00027404 0.00027367 0.00027342 0.00027323
#  0.00027318 0.00027286 0.00027268 0.00027251 0.00027242 0.00027196
#  0.00027191 0.00027158 0.00027135 0.00027122 0.00027098 0.00027071
#  0.00027066 0.0002705  0.00027028 0.00027    0.00026971 0.00026939
#  0.00026928 0.00026924 0.00026911 0.00026888 0.00026875 0.00026852
#  0.00026824 0.00026804 0.00026768 0.0002676  0.00026728 0.00026689
#  0.0002667  0.00026658 0.00026636 0.00026618 0.00026599 0.00026578
#  0.00026567 0.00026563 0.0002653  0.00026499 0.00026475 0.00026459
#  0.00026452 0.00026437 0.00026422 0.00026395 0.00026393 0.00026368
#  0.00026337 0.00026317 0.00026278 0.00026272 0.00026233 0.0002622
#  0.00026193 0.0002619  0.00026149 0.00026128 0.00026112 0.00026093
#  0.00026077 0.00026062 0.00026029 0.00026016 0.00026003 0.0002598
#  0.00025925 0.0002592  0.00025899 0.00025871 0.00025859 0.00025835
#  0.00025806 0.0002578  0.00025761 0.00025757 0.00025725 0.00025703
#  0.00025685 0.0002567  0.00025656 0.0002565  0.00025633 0.00025605
#  0.00025564 0.00025547 0.00025527 0.0002551  0.00025463 0.00025451
#  0.00025432 0.00025408 0.00025377 0.00025343 0.00025324 0.00025321
#  0.00025311 0.00025249 0.00025235 0.00025221 0.00025208 0.00025207
#  0.0002518  0.00025149 0.00025123 0.00025108 0.00025068 0.00025045
#  0.00025026 0.00025022 0.00025008 0.00024997 0.00024967 0.00024955
#  0.00024915 0.0002489  0.00024862 0.00024857 0.00024812 0.0002478
#  0.0002476  0.00024742 0.00024736 0.00024724 0.00024687 0.00024668
#  0.00024654 0.0002462  0.0002461  0.0002459  0.00024569 0.00024543
#  0.00024519 0.00024502 0.00024468 0.00024461 0.0002443  0.00024418
#  0.000244   0.00024376 0.00024349 0.00024326 0.00024304 0.00024287
#  0.00024257 0.00024232 0.00024213 0.00024195 0.00024154 0.00024129
#  0.00024124 0.000241   0.00024082 0.00024046 0.00024039 0.00024002
#  0.00023984 0.00023955 0.00023934 0.00023904 0.00023888 0.00023863
#  0.00023844 0.00023825 0.00023797 0.00023758 0.00023744 0.00023721
#  0.0002371  0.00023668 0.00023638 0.00023627 0.00023609 0.00023572
#  0.00023553 0.00023524 0.00023484 0.00023474 0.00023429 0.00023413
#  0.00023385 0.00023371 0.00023352 0.00023291 0.00023248 0.00023226
#  0.00023214 0.00023189 0.00023149 0.00023127 0.00023103 0.00023055
#  0.00023039 0.0002301  0.00022989 0.00022966 0.00022938 0.00022897
#  0.00022891 0.00022865 0.00022829 0.00022809 0.0002275  0.00022731
#  0.00022714 0.00022657 0.00022632 0.00022611]
# sum: 0.42234794823166244

# %%
tryNumComponents(2000)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  ... 0.00015304 0.00015284 0.00015253]
# sum: 0.6379269906255299

# %%
tryNumComponents(4000)
# Out:
# first n components: [4.24524879e-03 3.34695725e-03 2.59840014e-03 ... 7.15567984e-05
#  7.14729125e-05 7.13037498e-05]
# sum: 0.8928834173332065

# %%
# need to PCA first so it's computationally tractable to do tSNE
# based on results above, looks like doing numComponents = 4000 works fine, ~90% of variance
pca_4000 = sklearn.decomposition.PCA(n_components=4000)
pca_4000.fit(tfidf_scaled)
# Out:
# first n components: [0.00424525 0.00334696 0.0025984  0.00236336 0.00210052 0.00201037
#  0.001928   0.00178957 0.00169111 0.00164134 0.00156221 0.00152808
#  0.00145192 0.00140807 0.00138409 0.00133254 0.00126769 0.00124693
#  0.00118759 0.00109962 0.0010905  0.00108286 0.00105005 0.00102701
#  0.0010065  0.00098936 0.00094889 0.00094373 0.00093848 0.00092861
#  0.00090864 0.00089811 0.00089398 0.00088597 0.00087546 0.00086849
#  0.00085999 0.00085133 0.00084679 0.00083661 0.00083117 0.00082612
#  0.00081083 0.00080711 0.00079303 0.0007887  0.00078259 0.00077782
#  0.00077098 0.000761  ]
# sum: 0.06386434091825077

# %%
print 'first n components: ' + str((pca_4000.explained_variance_ratio_))
print 'sum: ' + str((np.sum(pca_4000.explained_variance_ratio_)))
# Out:
# first n components: [4.24524879e-03 3.34695725e-03 2.59840014e-03 ... 7.14050264e-05
#  7.13868350e-05 7.13139707e-05]
# sum: 0.8928813022488387

# %%
# transform scaled matrix
tfidf_pca_4000 = pca_4000.transform(tfidf_scaled)

# %%
# try tSNE on this
tfidf_embed = TSNE().fit_transform(tfidf_pca_4000)
print tfidf_embed.shape
# Out:
# (6100, 2)

# %%
plt.scatter(tfidf_embed[:,0], tfidf_embed[:,1])

# %%
# kmeans cluster on this bad boy
kmeans = KMeans(n_clusters=2, random_state=0).fit(tfidf_embed)
kmeans_labels = kmeans.labels_.reshape(6100,1).flatten()

dim1 = tfidf_embed[:,0]
dim2 = tfidf_embed[:,1]


plt.figure(figsize=(8,10))
plt.scatter(dim1[kmeans_labels == 0], dim2[kmeans_labels == 0], color = 'blue')
plt.scatter(dim1[kmeans_labels == 1], dim2[kmeans_labels == 1], color = 'red')

plt.xlabel('tsne one')
plt.ylabel('tsne two')
plt.legend(('Cluster 1', 'Cluster 2'))
plt.savefig('2kmeans_cluster_tsne.png')

# %%
# not sure that this is great, let's try 3 clusters?
# kmeans cluster on this bad boy
kmeans = KMeans(n_clusters=3, random_state=0).fit(tfidf_embed)
kmeans_labels = kmeans.labels_.reshape(6100,1).flatten()

dim1 = tfidf_embed[:,0]
dim2 = tfidf_embed[:,1]


plt.figure(figsize=(8,10))
plt.scatter(dim1[kmeans_labels == 0], dim2[kmeans_labels == 0], color = 'blue')
plt.scatter(dim1[kmeans_labels == 1], dim2[kmeans_labels == 1], color = 'red')
plt.scatter(dim1[kmeans_labels == 2], dim2[kmeans_labels == 2], color = 'green')


plt.xlabel('tsne one')
plt.ylabel('tsne two')
plt.legend(('Cluster 1', 'Cluster 2', 'Cluster 3'))
plt.savefig('3kmeans_cluster_tsne.png')

# %%
def printUniqueDrugs(unique_drug_list):
    unique_drug_names = []
    for num_drug in range(0, len(unique_drug_list)):
        curr_drug = unique_drug_list.iloc[num_drug]
        split_words = curr_drug.split("-")
        drug_name = split_words[0]
        if drug_name not in unique_drug_names:
            unique_drug_names.append(drug_name)

    print unique_drug_names

# %%
indices_cluster1 = kmeans_labels == 0
cluster1_drugs = tfidf_drug_names[indices_cluster1]
print(len(cluster1_drugs))

indices_cluster2 = kmeans_labels == 1
cluster2_drugs = tfidf_drug_names[indices_cluster2]
print(len(cluster2_drugs))

indices_cluster3 = kmeans_labels == 2
cluster3_drugs = tfidf_drug_names[indices_cluster3]
print(len(cluster3_drugs))
# Out:
# 5526
# 185
# 389

# %%
printUniqueDrugs(cluster2_drugs)
# Out:
# ['12,13', '4,5', '(+/', '(', '3', '4', '5155877', '6', 'AG', 'C', 'CP', 'LY', 'MK', 'N', 'N6', 'PF', 'PNU', 'Prestwick', 'SC', 'TTNPB', 'alpha', 'alprenolol', 'amiloride', 'amprolium', 'antimycin A', 'apomorphine', 'arachidonic acid', 'arachidonyltrifluoromethane', 'artemisinin', 'azathioprine', 'aztreonam', 'benperidol', 'benserazide', 'betaxolol', 'bisacodyl', 'bromopride', 'camptothecin', 'canavanine', 'celecoxib', 'chloramphenicol', 'chlormezanone', 'chlorpromazine', 'chlorpropamide', 'ciclosporin', 'cinnarizine', 'clofazimine', 'cobalt chloride', 'deferoxamine', 'dehydrocholic acid', 'demecolcine', 'dexamethasone', 'diazoxide', 'diclofenac', 'dicycloverine', 'dinoprostone', 'dopamine', 'dorzolamide', 'doxorubicin', 'eldeline', 'emetine', 'estradiol', 'etamsylate', 'ethambutol', 'ethaverine', 'ethionamide', 'ethosuximide', 'eticlopride', 'etofylline', 'fenspiride', 'fisetin', 'flucloxacillin', 'flufenamic acid', 'flumequine', 'flunarizine', 'flutamide', 'fulvestrant', 'furazolidone', 'fusidic acid', 'genistein', 'haloperidol', 'harmol', 'hydroquinine', 'hydroxyzine', 'iproniazid', 'irinotecan', 'isoflupredone', 'kaempferol', 'ketanserin', 'ketotifen', 'lomustine', 'loxapine', 'meclocycline', 'mephentermine', 'metanephrine', 'metergoline', 'metformin', 'methotrexate', 'methyldopa', 'meticrane', 'monastrol', 'monorden', 'morantel', 'naftidrofuryl', 'naphazoline', 'neomycin', 'nifedipine', 'nimesulide', 'nipecotic acid', 'nizatidine', 'nortriptyline', 'oleandomycin', 'paclitaxel', 'paroxetine', 'pentoxifylline', 'phenazone', 'phenindione', 'pheniramine', 'pirinixic acid', 'piroxicam', 'praziquantel', 'prednisone', 'pregnenolone', 'primidone', 'probucol', 'prochlorperazine', 'propoxycaine', 'pseudopelletierine', 'quinidine', 'quipazine', 'racecadotril', 'ranitidine', 'resveratrol', 'rofecoxib', 'rosiglitazone', 'sirolimus', 'sodium phenylbutyrate', 'splitomicin', 'staurosporine', 'sulfafurazole', 'sulfaphenazole', 'sulindac', 'tamoxifen', 'tanespimycin', 'terbutaline', 'tetroquinone', 'thapsigargin', 'theophylline', 'thiostrepton', 'tolazoline', 'tolmetin', 'tretinoin', 'triamcinolone', 'trichostatin A', 'valinomycin', 'valproic acid', 'vinpocetine', 'zalcitabine']

# %%
printUniqueDrugs(cluster3_drugs)
# Out:
# ['0175029', '0179445', '0317956', '15', '3', '5151277', '5182598', '5666823', 'AG', 'BCB000040', 'Chicago Sky Blue 6B', 'Gly', 'HC toxin', 'LM', 'LY', 'MS', 'Prestwick', 'R', 'STOCK1N', 'acetazolamide', 'acetylsalicylic acid', 'acetylsalicylsalicylic acid', 'amoxapine', 'amprolium', 'antazoline', 'asiaticoside', 'astemizole', 'atovaquone', 'atracurium besilate', 'atropine', 'azathioprine', 'benzonatate', 'bisacodyl', 'bupropion', 'calycanthine', 'cantharidin', 'carcinine', 'cefamandole', 'cefotaxime', 'chloramphenicol', 'chlorhexidine', 'chlorpromazine', 'chlorpropamide', 'cimetidine', 'cinoxacin', 'ciprofloxacin', 'clomipramine', 'clonidine', 'copper sulfate', 'cotinine', 'dantrolene', 'dapsone', 'denatonium benzoate', 'dequalinium chloride', 'desipramine', 'dexamethasone', 'diflunisal', 'digitoxigenin', 'digoxigenin', 'digoxin', 'dinoprostone', 'diphemanil metilsulfate', 'dipyridamole', 'docosahexaenoic acid ethyl ester', 'doxorubicin', 'eldeline', 'ellipticine', 'estradiol', 'ethambutol', 'ethisterone', 'ethotoin', 'exisulind', 'felodipine', 'finasteride', 'fluphenazine', 'fulvestrant', 'furosemide', 'genistein', 'glimepiride', 'glipizide', 'guanethidine', 'haloperidol', 'harmine', 'hecogenin', 'heliotrine', 'helveticoside', 'hexamethonium bromide', 'hydroflumethiazide', 'ifenprodil', 'iloprost', 'imatinib', 'indometacin', 'iodixanol', 'iohexol', 'ioversol', 'isometheptene', 'isoxsuprine', 'ivermectin', 'kanamycin', 'ketoprofen', 'lanatoside C', 'levobunolol', 'lorglumide', 'lumicolchicine', 'luteolin', 'mafenide', 'meclofenamic acid', 'mepyramine', 'mesalazine', 'metanephrine', 'metformin', 'methapyrilene', 'methylprednisolone', 'metitepine', 'midecamycin', 'minaprine', 'minocycline', 'mitoxantrone', 'monocrotaline', 'nicardipine', 'nipecotic acid', 'nitrendipine', 'nocodazole', 'norethisterone', 'novobiocin', 'orlistat', 'ouabain', 'oxamniquine', 'oxetacaine', 'oxytetracycline', 'ozagrel', 'pargyline', 'phenoxybenzamine', 'phenylpropanolamine', 'physostigmine', 'picrotoxinin', 'pirinixic acid', 'pirlindole', 'prednisolone', 'progesterone', 'propidium iodide', 'proscillaridin', 'pyrvinium', 'raloxifene', 'resveratrol', 'rifabutin', 'rosiglitazone', 'scoulerine', 'scriptaid', 'securinine', 'sirolimus', 'sotalol', 'staurosporine', 'streptomycin', 'strophanthidin', 'sulfadoxine', 'sulfathiazole', 'sulindac sulfide', 'tanespimycin', 'tetracycline', 'thalidomide', 'tocainide', 'tolazoline', 'tolfenamic acid', 'tolnaftate', 'tomatidine', 'tranexamic acid', 'trichostatin A', 'trimethobenzamide', 'trioxysalen', 'troleandomycin', 'tyloxapol', 'valproic acid', 'verapamil', 'verteporfin', 'vorinostat', 'zaprinast', 'zidovudine', 'zimeldine', 'zomepirac']

# %%
kmeans = KMeans(n_clusters=6, random_state=0).fit(tfidf_embed)
kmeans_labels = kmeans.labels_.reshape(6100,1).flatten()

dim1 = tfidf_embed[:,0]
dim2 = tfidf_embed[:,1]


plt.figure(figsize=(8,10))
plt.scatter(dim1[kmeans_labels == 0], dim2[kmeans_labels == 0], color = 'blue')
plt.scatter(dim1[kmeans_labels == 1], dim2[kmeans_labels == 1], color = 'red')
plt.scatter(dim1[kmeans_labels == 2], dim2[kmeans_labels == 2], color = 'green')
plt.scatter(dim1[kmeans_labels == 3], dim2[kmeans_labels == 3], color = 'purple')
plt.scatter(dim1[kmeans_labels == 4], dim2[kmeans_labels == 4], color = 'yellow')
plt.scatter(dim1[kmeans_labels == 5], dim2[kmeans_labels == 5], color = 'orange')





plt.xlabel('tsne one')
plt.ylabel('tsne two')
plt.legend(('Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4', 'Cluster 5', 'Cluster 6'))
plt.savefig('3kmeans_cluster_tsne.png')

# %%
indices_cluster2 = kmeans_labels == 1
cluster2_drugs = tfidf_drug_names[indices_cluster2]
print(len(cluster2_drugs))

indices_cluster3 = kmeans_labels == 2
cluster3_drugs = tfidf_drug_names[indices_cluster3]
print(len(cluster3_drugs))

indices_cluster5 = kmeans_labels == 4
cluster5_drugs = tfidf_drug_names[indices_cluster5]
print(len(cluster5_drugs))
# Out:
# 185
# 122
# 112

# %%
printUniqueDrugs(cluster2_drugs)
# Out:
# ['12,13', '4,5', '(+/', '(', '3', '4', '5155877', '6', 'AG', 'C', 'CP', 'LY', 'MK', 'N', 'N6', 'PF', 'PNU', 'Prestwick', 'SC', 'TTNPB', 'alpha', 'alprenolol', 'amiloride', 'amprolium', 'antimycin A', 'apomorphine', 'arachidonic acid', 'arachidonyltrifluoromethane', 'artemisinin', 'azathioprine', 'aztreonam', 'benperidol', 'benserazide', 'betaxolol', 'bisacodyl', 'bromopride', 'camptothecin', 'canavanine', 'celecoxib', 'chloramphenicol', 'chlormezanone', 'chlorpromazine', 'chlorpropamide', 'ciclosporin', 'cinnarizine', 'clofazimine', 'cobalt chloride', 'deferoxamine', 'dehydrocholic acid', 'demecolcine', 'dexamethasone', 'diazoxide', 'diclofenac', 'dicycloverine', 'dinoprostone', 'dopamine', 'dorzolamide', 'doxorubicin', 'eldeline', 'emetine', 'estradiol', 'etamsylate', 'ethambutol', 'ethaverine', 'ethionamide', 'ethosuximide', 'eticlopride', 'etofylline', 'fenspiride', 'fisetin', 'flucloxacillin', 'flufenamic acid', 'flumequine', 'flunarizine', 'flutamide', 'fulvestrant', 'furazolidone', 'fusidic acid', 'genistein', 'haloperidol', 'harmol', 'hydroquinine', 'hydroxyzine', 'iproniazid', 'irinotecan', 'isoflupredone', 'kaempferol', 'ketanserin', 'ketotifen', 'lomustine', 'loxapine', 'meclocycline', 'mephentermine', 'metanephrine', 'metergoline', 'metformin', 'methotrexate', 'methyldopa', 'meticrane', 'monastrol', 'monorden', 'morantel', 'naftidrofuryl', 'naphazoline', 'neomycin', 'nifedipine', 'nimesulide', 'nipecotic acid', 'nizatidine', 'nortriptyline', 'oleandomycin', 'paclitaxel', 'paroxetine', 'pentoxifylline', 'phenazone', 'phenindione', 'pheniramine', 'pirinixic acid', 'piroxicam', 'praziquantel', 'prednisone', 'pregnenolone', 'primidone', 'probucol', 'prochlorperazine', 'propoxycaine', 'pseudopelletierine', 'quinidine', 'quipazine', 'racecadotril', 'ranitidine', 'resveratrol', 'rofecoxib', 'rosiglitazone', 'sirolimus', 'sodium phenylbutyrate', 'splitomicin', 'staurosporine', 'sulfafurazole', 'sulfaphenazole', 'sulindac', 'tamoxifen', 'tanespimycin', 'terbutaline', 'tetroquinone', 'thapsigargin', 'theophylline', 'thiostrepton', 'tolazoline', 'tolmetin', 'tretinoin', 'triamcinolone', 'trichostatin A', 'valinomycin', 'valproic acid', 'vinpocetine', 'zalcitabine']

# %%
printUniqueDrugs(cluster3_drugs)
# Out:
# ['0317956', '15', '3', '5151277', '5182598', '5666823', 'AG', 'BCB000040', 'Chicago Sky Blue 6B', 'Gly', 'LM', 'LY', 'Prestwick', 'acetazolamide', 'acetylsalicylic acid', 'amprolium', 'astemizole', 'atovaquone', 'atracurium besilate', 'atropine', 'azathioprine', 'benzonatate', 'bupropion', 'calycanthine', 'cantharidin', 'chloramphenicol', 'chlorhexidine', 'chlorpromazine', 'chlorpropamide', 'cimetidine', 'cinoxacin', 'clomipramine', 'clonidine', 'copper sulfate', 'cotinine', 'denatonium benzoate', 'dequalinium chloride', 'desipramine', 'dexamethasone', 'dipyridamole', 'docosahexaenoic acid ethyl ester', 'eldeline', 'estradiol', 'ethambutol', 'ethisterone', 'ethotoin', 'felodipine', 'finasteride', 'fluphenazine', 'fulvestrant', 'genistein', 'glimepiride', 'guanethidine', 'haloperidol', 'hecogenin', 'heliotrine', 'hexamethonium bromide', 'hydroflumethiazide', 'iloprost', 'imatinib', 'indometacin', 'iodixanol', 'iohexol', 'isoxsuprine', 'ivermectin', 'kanamycin', 'ketoprofen', 'levobunolol', 'luteolin', 'mafenide', 'mepyramine', 'mesalazine', 'metformin', 'metitepine', 'midecamycin', 'minocycline', 'nipecotic acid', 'nocodazole', 'norethisterone', 'novobiocin', 'orlistat', 'pargyline', 'physostigmine', 'pirinixic acid', 'prednisolone', 'progesterone', 'raloxifene', 'resveratrol', 'securinine', 'sirolimus', 'sotalol', 'staurosporine', 'sulfathiazole', 'sulindac sulfide', 'tanespimycin', 'tetracycline', 'tocainide', 'tolazoline', 'tolnaftate', 'tomatidine', 'tranexamic acid', 'trimethobenzamide', 'trioxysalen', 'troleandomycin', 'tyloxapol', 'valproic acid', 'verapamil', 'verteporfin', 'zaprinast', 'zidovudine', 'zimeldine', 'zomepirac']

# %%
printUniqueDrugs(cluster5_drugs)
# Out:
# ['4,5', '(+/', '3', '4', 'CP', 'LY', 'N', 'N6', 'PF', 'PNU', 'Prestwick', 'alpha', 'alprenolol', 'amiloride', 'amprolium', 'apomorphine', 'arachidonic acid', 'arachidonyltrifluoromethane', 'azathioprine', 'aztreonam', 'bromopride', 'camptothecin', 'celecoxib', 'chloramphenicol', 'chlorpromazine', 'ciclosporin', 'cinnarizine', 'clofazimine', 'cobalt chloride', 'deferoxamine', 'dehydrocholic acid', 'demecolcine', 'diazoxide', 'dicycloverine', 'eldeline', 'emetine', 'etamsylate', 'ethambutol', 'ethaverine', 'ethionamide', 'ethosuximide', 'etofylline', 'fenspiride', 'flucloxacillin', 'flumequine', 'flutamide', 'fulvestrant', 'furazolidone', 'haloperidol', 'harmol', 'hydroquinine', 'iproniazid', 'isoflupredone', 'kaempferol', 'ketanserin', 'ketotifen', 'lomustine', 'mephentermine', 'metergoline', 'metformin', 'methotrexate', 'methyldopa', 'meticrane', 'monastrol', 'monorden', 'morantel', 'nifedipine', 'nipecotic acid', 'nizatidine', 'oleandomycin', 'paclitaxel', 'paroxetine', 'pentoxifylline', 'phenazone', 'phenindione', 'piroxicam', 'praziquantel', 'primidone', 'probucol', 'propoxycaine', 'quinidine', 'quipazine', 'racecadotril', 'resveratrol', 'rofecoxib', 'rosiglitazone', 'sirolimus', 'sodium phenylbutyrate', 'splitomicin', 'staurosporine', 'sulfaphenazole', 'tamoxifen', 'terbutaline', 'tetroquinone', 'thapsigargin', 'thiostrepton', 'tolazoline', 'tolmetin', 'tretinoin', 'trichostatin A', 'valproic acid', 'vinpocetine']

# %%
# do the clustering instead with hierarchical clustering
cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')  
cluster.fit_predict(tfidf_embed) 

cluster_labs = cluster.labels_

dim1 = tfidf_embed[:,0]
dim2 = tfidf_embed[:,1]

plt.figure(figsize=(8,10))
plt.scatter(dim1[cluster_labs == 0], dim2[cluster_labs == 0], color = 'blue')
plt.scatter(dim1[cluster_labs == 1], dim2[cluster_labs == 1], color = 'red')

plt.xlabel('tsne one')
plt.ylabel('tsne two')
plt.legend(('Cluster 1', 'Cluster 2'))
plt.savefig('2clust_hierarch_cluster_tsne.png')

# %%
indices_cluster1 = kmeans_labels == 0
cluster1_drugs = tfidf_drug_names[indices_cluster1]
print(len(cluster1_drugs))

indices_cluster2 = kmeans_labels == 1
cluster2_drugs = tfidf_drug_names[indices_cluster2]
print(len(cluster2_drugs))
# Out:
# 1890
# 128

# %%
printUniqueDrugs(cluster2_drugs)
# Out:
# ['12,13', '(', '0175029', '0179445', '3', '5155877', '6', 'AG', 'C', 'CP', 'LM', 'MK', 'Prestwick', 'R', 'SC', 'STOCK1N', 'TTNPB', 'acetylsalicylsalicylic acid', 'amoxapine', 'antimycin A', 'artemisinin', 'benperidol', 'benserazide', 'betaxolol', 'bisacodyl', 'canavanine', 'carcinine', 'cefotaxime', 'celecoxib', 'chlormezanone', 'chlorpropamide', 'copper sulfate', 'dantrolene', 'dapsone', 'dexamethasone', 'diclofenac', 'diflunisal', 'dinoprostone', 'diphemanil metilsulfate', 'dopamine', 'dorzolamide', 'doxorubicin', 'estradiol', 'eticlopride', 'exisulind', 'fisetin', 'flufenamic acid', 'flunarizine', 'fulvestrant', 'furosemide', 'fusidic acid', 'genistein', 'glipizide', 'hydroxyzine', 'ifenprodil', 'ioversol', 'irinotecan', 'isometheptene', 'lorglumide', 'loxapine', 'lumicolchicine', 'meclocycline', 'meclofenamic acid', 'metanephrine', 'methapyrilene', 'methylprednisolone', 'minaprine', 'monocrotaline', 'monorden', 'naftidrofuryl', 'naphazoline', 'neomycin', 'nicardipine', 'nimesulide', 'nitrendipine', 'nortriptyline', 'oxamniquine', 'oxetacaine', 'oxytetracycline', 'ozagrel', 'pheniramine', 'phenoxybenzamine', 'pirinixic acid', 'prednisone', 'pregnenolone', 'prochlorperazine', 'propidium iodide', 'pseudopelletierine', 'raloxifene', 'ranitidine', 'resveratrol', 'rofecoxib', 'rosiglitazone', 'scoulerine', 'sirolimus', 'sodium phenylbutyrate', 'streptomycin', 'sulfadoxine', 'sulfafurazole', 'sulindac', 'tamoxifen', 'tanespimycin', 'thalidomide', 'theophylline', 'tolnaftate', 'triamcinolone', 'trichostatin A', 'valinomycin', 'valproic acid', 'zalcitabine', 'zidovudine']

# %%
unique_drug_names = []
for num_drug in range(0, len(cluster2_drugs)):
    curr_drug = cluster2_drugs.iloc[num_drug]
    split_words = curr_drug.split("-")
    drug_name = split_words[0]
    if drug_name not in unique_drug_names:
        unique_drug_names.append(drug_name)

# %%
(set(test_set_strings)).intersection(set(unique_drug_names))
# Out:
# set()

# %%
# so the test drugs are all in the bigger cluster.... not necessarily helpful since everything is in 1 clust

# %%
# i want more information- i don't want to use PCA, i want to t-sne on the full set
full_tfidf_embed = TSNE().fit_transform(tfidf_scaled)
print full_tfidf_embed.shape

# %%
plt.scatter(tfidf_embed[:,0], tfidf_embed[:,1])
